# %% [markdown]
# <a href="https://colab.research.google.com/github/saimeonver/PythonExercise/blob/main/PythonExercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#python alıştırmaları

# %%
#Görev 1 : Verilen değerlerin veri yapılarnıinceleyin

x = 8

y = 3.2

z = 8j + 18

a = "Hello World"

b = True

c = 23 < 22

l = [1, 2, 3, 4]

d = {"Name": "Jack",
     "Age":27,
     "Adress":"Downtown"}

t = ("Machine Learning","Data Science")

s = {"Python", "Machine Learning",
     "Data Science"}

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
type(a)
# Out:
# str

# %%
type(b)
# Out:
# bool

# %%
type(c)
# Out:
# bool

# %%
type(l)
# Out:
# list

# %%
type(d)
# Out:
# dict

# %%
type(t)
# Out:
# tuple

# %%
type(s)
# Out:
# set

# %%
#Görev 2 : Verilen string ifadenin tüm harflerini
#büyük harfe çevirin. Virgül ve nokta yerine space koyun

text = "The goal is the turn data into information, and information into insight. "

# %%
for i in text:
  i.upper().replace()

# %%
#gorev 3 :verilen listeye asagıdki adımlıuygulayın
lst = ["D","A","T","A","S","C","I","E","N","C","E"]

# %%
#adım 1 : verilen listenin eleman sayısına bakınız
#adım 2: sıfırıncı ve onuncu indeksteki elemanları cagırın
#adım 3 : verilen liste üzerinden ["D","A","T"],"A"
#litesini oluşturunuz
#adım 4 :8. indeksteki elemanı silinz
#adım 5: yen bir eleman ekleyin
#adım 6: sekizinci indekse "N" elemanunı tekrarekleyin

# %%
#gorev4: verilen sözlük yapısına aşağıdaki adımları
#uygulayın
dict = {"Christian": ["America",18],
        "Daisy": ["England",12],
        "Antonio":["Spain",22],
        "Dante":["Italy",25]}

# %%
#Adım 1: key değerlerine erişiniz
#adım 2: value değerlerine erişinz
#adım 3: daisy key ine ait 12 değerini 13 olarak güncelleyin
